# %%
import pandas as pd

# %%
db=pd.read_csv('data/250929_공공데이터_제공_대체사이트_안내(113개)(CSV).csv')
db.head(5)
# Out:
#    번호      유형          시스템명                     URL      기관명
# 0   1  개방전용포털  교통사고정보 개방시스템  taas.koroad.or.kr/api/   도로교통공단
# 1   2  개방전용포털      국가교통정보센터               its.go.kr    국토교통부
# 2   3  개방전용포털      기상자료개방포털          data.kma.go.kr      기상청
# 3   4  개방전용포털   농식품 공공데이터포털        data.mafra.go.kr  농림축산식품부
# 4   5  개방전용포털       국가서지LOD            lod.nl.go.kr  국립중앙도서관

# %%
db.size
# Out:
# 565
